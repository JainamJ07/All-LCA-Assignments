# %%
n = float(input("Enter the number"))

sum = 0

while n>0:
 digit = n % 10
 sum = sum + digit 
 n = n//10

print("Sum of the digis is =" , sum)
# Out:
# Enter the number 12
# Sum of the digis is = 3.0

# %%
a = float(input("Enter the marks"))

if 100 >= a >= 90:
    print("Grade O")
elif 89 >= a >= 80:
    print("Grade A+")
elif 79 >= a >= 70: 
    print("Grade A")
elif 69 >= a >= 60: 
    print("Grade B")
elif 59 >= a >= 50: 
    print("Grade C")
elif 49 >= a >= 40: 
    print("Grade P")
else :
    print("Grade F")
# Out:
# Enter the marks 91
# Grade O

# %%
num = int(input("Enter a number"))
factorial = 1 

for i in range(1,num + 1):
    factorial = factorial*i

print("Factorial of the number is:",factorial)
# Out:
# Enter a number 5
# Factorial of the number is: 120

# %%
num = int(input("Enter the number"))

if num <= 1:
    print("The number is not prime")
else:
    prime = True

    for i in range(2,num):
      if num % i==0:
        prime = False 
        break 

if prime:
    print("The number is a prime")
else:
    print("Number is not a prime number")
# Out:
# Enter the number 5
# The number is a prime

# %%
for i in range(5):
 num = int(input("Enter a number"))
 cube = num**3
 print("Cube =",cube)
# Out:
# Enter a number 1
# Cube = 1
# Enter a number 2
# Cube = 8
# Enter a number 3
# Cube = 27
# Enter a number 4
# Cube = 64
# Enter a number 5
# Cube = 125

# %%
num = int(input("Enter a number"))

reverse = 0

while num>0:
    digit = num%10
    reverse = reverse*10 + digit 
    num = num // 10

print("Reverse =", reverse)
# Out:
# Enter a number 42
# Reverse = 24

# %%
year = int(input("Enter a year:"))

if year % 400 == 0:
    print("This year is a leap year")
elif year % 100 == 0:
    print("This year is not a leap year")
elif year % 4 == 0:
    print("The year is a leap year")
else:
    print("The year is not a leap year")
# Out:
# Enter a year: 2025
# The year is not a leap year

# %%
numbers = [10,20,30,40,50]
print("List:",numbers)
print("First element:",numbers[0])
print("Second element:",numbers[1])
print("Third element:",numbers[2])
print("Fourth element:",numbers[3])
print("fifth element:",numbers[4])
# Out:
# List: [10, 20, 30, 40, 50]
# First element: 10
# Second element: 20
# Third element: 30
# Fourth element: 40
# fifth element: 50

# %%
Student_name = str(input("Enter your name:"))
Address = str(input("Enter your addresss:"))
Cotact_no = int(input("Enter your contact number:"))
Mother_toungue = str(input("Enter your mother toungue:"))
School_name = str(input("Enter your school name:"))
Year = int(input("Enter your year:"))
Panel = str(input("Enter your panel:"))
Roll_no = int(input("Enter your roll number:"))

print("Name:" , Student_name)
print("Address:" , Address)
print("Contact_no:" , Cotact_no)
print("Mother_toungue:" , Mother_toungue)
print("School_name:" , School_name)
print("Year:" , Year)
print("Panel:" , Panel)
print("Roll_no:" , Roll_no)
# Out:
# Enter your name: erhh
# Enter your addresss: sjj
# Enter your contact number: 515
# Enter your mother toungue: srjsj
# Enter your school name: sjj
# Enter your year: 31
# Enter your panel: sjsj
# Enter your roll number: 31
# Name: erhh
# Address: sjj
# Contact_no: 515
# Mother_toungue: srjsj
# School_name: sjj
# Year: 31
# Panel: sjsj
# Roll_no: 31

# %%
Student_name = str(input("Enter your name:"))

"""
Address = str(input("Enter your addresss:"))
Cotact_no = int(input("Enter your contact number:"))
Mother_toungue = str(input("Enter your mother toungue:"))
"""

School_name = str(input("Enter your school name:"))
Year = int(input("Enter your year:"))
Panel = str(input("Enter your panel:"))
Roll_no = int(input("Enter your roll number:"))

print("Name:" , Student_name)
print("Address:" , Address)
print("Contact_no:" , Cotact_no)
print("Mother_toungue:" , Mother_toungue)
print("School_name:" , School_name)
print("Year:" , Year)
print("Panel:" , Panel)
print("Roll_no:" , Roll_no)

# %%
Name = str(input("Enter your name:"))
p = float(input("Enter your physics marks:"))
c = float(input("Enter your chemistry marks:"))
m = float(input("Enter your Maths marks:"))

percentage = ((p+c+m)/3)  

print("Your total percentage for PCM is:" , percentage)

#For greatest

if m >= p and m>=c:
    if m == p:
        print("Maths and physics has greatest marks , with marks =", m)
    elif m == c:
        print("Maths and chemistry has greatest marks , with marks =", m)
    else : 
        print("Maths has the Greatest marks , with marks=", m)
elif p>= m  and p>= c:
     if p == m:
        print("Maths and physics has greatest marks , with marks =", p)
     elif p == c:
        print("Physics and chemistry has greatest marks , with marks =", p)
     else :
        print("Physics has the Greatest marks , with marks=", p)
else :
    if c == p:
        print("Chemistry and physics has greatest marks , with marks =", c)
    elif c == m:
        print("Maths and chemistry has greatest marks , with marks =", c)
    else : 
        print("Chemistry has the Greatest marks , with makrs=", c)

#For lowest

if m <= p and m<=c:
    if m == p:
        print("Maths and physics has Lowest marks , with marks =", m)
    elif m == c:
        print("Maths and chemistry has Lowest marks , with marks =", m)
    else : 
        print("Maths has the Lowest marks , with marks=", m)
elif p<= m  and p<= c:
     if p == m:
        print("Maths and physics has lowest marks , with marks =", p)
     elif p == c:
        print("Physics and chemistry has lowest marks , with marks =", p)
     else :
        print("Physics has the lowest marks , with marks=", p)
else :
    if c == p:
        print("Chemistry and physics has lowest marks , with marks =", c)
    elif c == m:
        print("Maths and chemistry has lowest marks , with marks =", c)
    else : 
        print("Chemistry has the Greatest marks , with makrs=", c)
# Out:
# Enter your name: Jainam
# Enter your physics marks: 85
# Enter your chemistry marks: 90
# Enter your Maths marks: 95
# Your total percentage for PCM is: 90.0
# Maths has the Greatest marks , with marks= 95.0
# Physics has the lowest marks , with marks= 85.0
